# %% [markdown]
# Read CSV

# %%
import pandas as pd

ohlc = pd.read_csv("BTCUSDT.csv.gz")
ohlc.head()
# Out:
#             Date      Open     Close       Low      High  BaseVolume  \
# 0  1514764800000  13715.65  13694.92  13666.11  13715.65    4.957404
# 1  1514764860000  13707.91  13680.00  13666.11  13707.91    3.459549
# 2  1514764920000  13682.00  13645.99  13601.00  13694.94   12.935828
# 3  1514764980000  13679.98  13600.00  13576.28  13679.98   27.313983
# 4  1514765040000  13645.98  13568.00  13554.44  13646.00   22.119789
#
#      QuoteVolume
# 0   38931.004413
# 1   28910.982501
# 2  157962.177508
# 3  213978.120703
# 4  213978.120703

# %% [markdown]
# Calculate Indicators

# %%
from ta.volatility import BollingerBands
import signals
from ta import momentum, volume, volatility;
import importlib
importlib.reload(signals)

minimum_deviation = 0.01

kline_count = len(ohlc['Date'])
zigzag = signals.zigzag(ohlc, 'High', 'Low', minimum_deviation)
effective_price = ohlc['QuoteVolume'] / ohlc['BaseVolume']
rsi7 = momentum.rsi(ohlc['Close'], 7)
rsi14 = momentum.rsi(ohlc['Close'], 14)
rsi21 = momentum.rsi(ohlc['Close'], 21)
mfi7 = volume.money_flow_index(
    high=ohlc['High'], low=ohlc['Low'], close=ohlc['Close'], volume=ohlc['QuoteVolume'], window=7)
mfi14 = volume.money_flow_index(
    high=ohlc['High'], low=ohlc['Low'], close=ohlc['Close'], volume=ohlc['QuoteVolume'], window=14)
mfi21 = volume.money_flow_index(
    high=ohlc['High'], low=ohlc['Low'], close=ohlc['Close'], volume=ohlc['QuoteVolume'], window=21)

# %% [markdown]
# Prepare datasets

# %%
import numpy as np
import numpy.ma as ma

sigs = signals.split_signals(zigzag)

long_signal_count = len(sigs["long"])
short_signal_count = len(sigs["short"])

signal_count = long_signal_count + short_signal_count
signal_period = min(sigs["long"][0], sigs["short"][1], round(kline_count / signal_count))

columns = ["Date", "Long", "Neutral", "Short"] \
    + [f"rsi7_{i}" for i in range(signal_period)]  \
    + [f"rsi14_{i}" for i in range(signal_period)]  \
    + [f"rsi21_{i}" for i in range(signal_period)]  \
    + [f"mfi7_{i}" for i in range(signal_period)]  \
    + [f"mfi14_{i}" for i in range(signal_period)]  \
    + [f"mfi21_{i}" for i in range(signal_period)] \

#+ [f"effective_price_{i}" for i in range(signal_period)] \
#+ [f"quote_volume_{i}" for i in range(signal_period)] \

signal_options = [
    [0, 1, 0], #Neutral
    [1, 0, 0], #Long
    [0, 0, 1], #Short
]

df = pd.DataFrame(
    [ma.concatenate([
        [ohlc['Date'][sigs["short"][i]]],
        signal_options[-1],
        #effective_price[sigs["short"][i] -
        #                signal_period:sigs["short"][i]].values,
        #ohlc['QuoteVolume'][sigs["short"][i] -
        #                signal_period:sigs["short"][i]].values,
        rsi7[sigs["short"][i] - signal_period:sigs["short"][i]].values,
        rsi14[sigs["short"][i] - signal_period:sigs["short"][i]].values,
        rsi21[sigs["short"][i] - signal_period:sigs["short"][i]].values,
        mfi7[sigs["short"][i] - signal_period:sigs["short"][i]].values,
        mfi14[sigs["short"][i] - signal_period:sigs["short"][i]].values,
        mfi21[sigs["short"][i] - signal_period:sigs["short"][i]].values,
    ])
        for i in range(short_signal_count)] +
    [ma.concatenate([
        [ohlc['Date'][sigs["long"][i]]],
        signal_options[1],
        #effective_price[sigs["long"][i] -
        #                signal_period:sigs["long"][i]].values,
        #ohlc['QuoteVolume'][sigs["long"][i] -
        #                    signal_period:sigs["long"][i]].values,
        rsi7[sigs["long"][i] - signal_period:sigs["long"][i]].values,
        rsi14[sigs["long"][i] - signal_period:sigs["long"][i]].values,
        rsi21[sigs["long"][i] - signal_period:sigs["long"][i]].values,
        mfi7[sigs["long"][i] - signal_period:sigs["long"][i]].values,
        mfi14[sigs["long"][i] - signal_period:sigs["long"][i]].values,
        mfi21[sigs["long"][i] - signal_period:sigs["long"][i]].values,
    ])
        for i in range(long_signal_count)], columns=columns).dropna()

print(
    f"generated data for {df.shape[0]} signals with signal period of {signal_period}. {signal_count - df.shape[0]} rows was empty")

signal_count = df.shape[0]

shuffled_df = df.sample(frac=1).reset_index(drop=True)
# Out:
# generated data for 10669 signals with signal period of 200. 53 rows was empty

# %% [markdown]
# Split data for training, validation and test

# %%
training_percentage = 0.9
validation_percentage = 0.05

training_data_count = round(signal_count * training_percentage)
validation_data_count = round(signal_count * validation_percentage)
test_data_count = signal_count - validation_data_count - training_data_count

training_df = shuffled_df.iloc[0:training_data_count, :]
training_df_x = training_df.drop(['Date', 'Long', 'Short', 'Neutral'], axis=1)
training_df_y = training_df[['Long', 'Neutral', 'Short']]

validation_df = shuffled_df.iloc[training_data_count:
                        validation_data_count + training_data_count, :]
validation_df_x = validation_df.drop(
    ['Date', 'Long', 'Short', 'Neutral'], axis=1)
validation_df_y = validation_df[['Long', 'Neutral', 'Short']]

test_df = shuffled_df.iloc[validation_data_count + training_data_count:, :]
test_df_x = test_df.drop(
    ['Date', 'Long', 'Short', 'Neutral'], axis=1)
test_df_y = test_df[['Long', 'Neutral', 'Short']]

# %% [markdown]
# Create a model and train

# %%
import os
from tensorflow import keras

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

input_layer_size = training_df_x.shape[1]
output_layer_size = training_df_y.shape[1]

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(input_layer_size, 1)),
    keras.layers.Dense(output_layer_size, activation="softmax"),
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(training_df_x, training_df_y, epochs=100)

results = model.evaluate(validation_df_x, validation_df_y)
print("test loss, test acc:", results)

results = model.evaluate(test_df_x, test_df_y)
print("test loss, test acc:", results)
# Out:
# Epoch 1/100
# 301/301 [==============================] - 1s 2ms/step - loss: 2.1816 - accuracy: 0.8048
# Epoch 2/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.8936 - accuracy: 0.8859
# Epoch 3/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.7443 - accuracy: 0.9054
# Epoch 4/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5295 - accuracy: 0.9275
# Epoch 5/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4982 - accuracy: 0.9248
# Epoch 6/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.7972 - accuracy: 0.9150
# Epoch 7/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4694 - accuracy: 0.9316
# Epoch 8/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5246 - accuracy: 0.9231
# Epoch 9/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4759 - accuracy: 0.9417
# Epoch 10/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4958 - accuracy: 0.9355
# Epoch 11/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4395 - accuracy: 0.9373
# Epoch 12/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3460 - accuracy: 0.9444
# Epoch 13/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4068 - accuracy: 0.9370
# Epoch 14/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4138 - accuracy: 0.9430
# Epoch 15/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3938 - accuracy: 0.9427
# Epoch 16/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4105 - accuracy: 0.9421
# Epoch 17/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3678 - accuracy: 0.9432
# Epoch 18/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4617 - accuracy: 0.9372
# Epoch 19/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4872 - accuracy: 0.9358
# Epoch 20/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4757 - accuracy: 0.9404
# Epoch 21/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3743 - accuracy: 0.9461
# Epoch 22/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4276 - accuracy: 0.9351
# Epoch 23/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5038 - accuracy: 0.9396
# Epoch 24/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3716 - accuracy: 0.9472
# Epoch 25/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4230 - accuracy: 0.9413
# Epoch 26/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6115 - accuracy: 0.9374
# Epoch 27/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4559 - accuracy: 0.9406
# Epoch 28/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3965 - accuracy: 0.9501
# Epoch 29/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4357 - accuracy: 0.9456
# Epoch 30/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3723 - accuracy: 0.9489
# Epoch 31/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5965 - accuracy: 0.9341
# Epoch 32/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3664 - accuracy: 0.9523
# Epoch 33/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4596 - accuracy: 0.9482
# Epoch 34/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4695 - accuracy: 0.9489
# Epoch 35/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3175 - accuracy: 0.9526
# Epoch 36/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4151 - accuracy: 0.9420
# Epoch 37/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3220 - accuracy: 0.9513
# Epoch 38/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4084 - accuracy: 0.9466
# Epoch 39/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3878 - accuracy: 0.9484
# Epoch 40/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3464 - accuracy: 0.9552
# Epoch 41/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4784 - accuracy: 0.9422
# Epoch 42/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4228 - accuracy: 0.9479
# Epoch 43/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5195 - accuracy: 0.9394
# Epoch 44/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4139 - accuracy: 0.9472
# Epoch 45/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4999 - accuracy: 0.9475
# Epoch 46/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4203 - accuracy: 0.9478
# Epoch 47/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4497 - accuracy: 0.9513
# Epoch 48/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5103 - accuracy: 0.9400
# Epoch 49/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3771 - accuracy: 0.9583
# Epoch 50/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3826 - accuracy: 0.9482
# Epoch 51/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.9506
# Epoch 52/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4292 - accuracy: 0.9448
# Epoch 53/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5724 - accuracy: 0.9368
# Epoch 54/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6143 - accuracy: 0.9428
# Epoch 55/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3660 - accuracy: 0.9569
# Epoch 56/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5546 - accuracy: 0.9452
# Epoch 57/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4279 - accuracy: 0.9550
# Epoch 58/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3828 - accuracy: 0.9537
# Epoch 59/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3975 - accuracy: 0.9479
# Epoch 60/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4121 - accuracy: 0.9534
# Epoch 61/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4024 - accuracy: 0.9552
# Epoch 62/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3492 - accuracy: 0.9557
# Epoch 63/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3974 - accuracy: 0.9499
# Epoch 64/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4085 - accuracy: 0.9522
# Epoch 65/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3861 - accuracy: 0.9517
# Epoch 66/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4088 - accuracy: 0.9483
# Epoch 67/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4858 - accuracy: 0.9437
# Epoch 68/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5142 - accuracy: 0.9457
# Epoch 69/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5045 - accuracy: 0.9500
# Epoch 70/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3871 - accuracy: 0.9520
# Epoch 71/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4332 - accuracy: 0.9443
# Epoch 72/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3977 - accuracy: 0.9515
# Epoch 73/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3931 - accuracy: 0.9507
# Epoch 74/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5459 - accuracy: 0.9408
# Epoch 75/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4530 - accuracy: 0.9497
# Epoch 76/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4134 - accuracy: 0.9550
# Epoch 77/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.2935 - accuracy: 0.9613
# Epoch 78/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5563 - accuracy: 0.9500
# Epoch 79/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3361 - accuracy: 0.9587
# Epoch 80/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4584 - accuracy: 0.9437
# Epoch 81/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.9456
# Epoch 82/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5049 - accuracy: 0.9438
# Epoch 83/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4256 - accuracy: 0.9496
# Epoch 84/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4221 - accuracy: 0.9506
# Epoch 85/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3765 - accuracy: 0.9544
# Epoch 86/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3746 - accuracy: 0.9580
# Epoch 87/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4535 - accuracy: 0.9478
# Epoch 88/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4321 - accuracy: 0.9496
# Epoch 89/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3952 - accuracy: 0.9534
# Epoch 90/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3728 - accuracy: 0.9512
# Epoch 91/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3547 - accuracy: 0.9574
# Epoch 92/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4386 - accuracy: 0.9546
# Epoch 93/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4421 - accuracy: 0.9508
# Epoch 94/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5097 - accuracy: 0.9481
# Epoch 95/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4736 - accuracy: 0.9443
# Epoch 96/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4037 - accuracy: 0.9581
# Epoch 97/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3792 - accuracy: 0.9588
# Epoch 98/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3914 - accuracy: 0.9511
# Epoch 99/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3780 - accuracy: 0.9518
# Epoch 100/100
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5193 - accuracy: 0.9420
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5435 - accuracy: 0.9325
# test loss, test acc: [0.5435283184051514, 0.9324578046798706]
# 17/17 [==============================] - 0s 1ms/step - loss: 0.5772 - accuracy: 0.9419
# test loss, test acc: [0.5772069692611694, 0.9419475793838501]

# %% [markdown]
# Predict today

# %%
X = df.drop(['Date', 'Long', 'Short', 'Neutral'], axis=1)[5, :]
Y = df[['Date', 'Long', 'Short', 'Neutral']]
print(X[5, :])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(5, slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /home/bariscumhur/Applications/crypot/python/training_1.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/bariscumhur/Applications/crypot/python/training_1.ipynb#ch0000018?line=0'>1</a> X = df.drop(['Date', 'Long', 'Short', 'Neutral'], axis=1)[5, :]
#       <a href='vscode-notebook-cell:/home/bariscumhur/Applications/crypot/python/training_1.ipynb#ch0000018?line=1'>2</a> Y = df[['Date', 'Long', 'Short', 'Neutral']]
#       <a href='vscode-notebook-cell:/home/bariscumhur/Applications/crypot/python/training_1.ipynb#ch0000018?line=2'>3</a> print(X[5, :])
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>         raise KeyError(key) from err
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a>     except TypeError:
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>         # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>         #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>         #  the TypeError.
# -> <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>         self._check_indexing_error(key)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3628'>3629</a>         raise
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3630'>3631</a> # GH#42269
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:5637, in Index._check_indexing_error(self, key)
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5632'>5633</a> def _check_indexing_error(self, key):
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5633'>5634</a>     if not is_scalar(key):
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5634'>5635</a>         # if key is not a scalar, directly raise an error (the code below
#    <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5635'>5636</a>         # would convert to numpy arrays and raise later any way) - GH29926
# -> <a href='file:///home/bariscumhur/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=5636'>5637</a>         raise InvalidIndexError(key)
#
# InvalidIndexError: (5, slice(None, None, None))
